# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\bianc\\PycharmProjects\\BiancaLages\\Sprint_5\\Desafio\\arrecadacao-estado.csv', delimiter=';', encoding='latin1')
numeric_cols = df.columns[3:]  # Seleciona as colunas a partir da terceira
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')
# Renomear colunas
df.rename(columns={'IPI - AUTOMÓVEIS': 'IPI_Automoveis'}, inplace=True)
df['IPI_Automoveis'] = pd.to_numeric(df['IPI_Automoveis'], errors='coerce')
df['IPI - VINCULADO À IMPORTACAO'] = pd.to_numeric(df['IPI - VINCULADO À IMPORTACAO'], errors='coerce')

# ESTADOS COM ARRECADAÇÃO DE IPI- AUTOMÓVEIS ACIMA DE 10 MILHÕES E IPI- VINCULADO À IMPORTAÇÃO ACIMA DE 5 MILHÕES
filtro = (df['IPI_Automoveis'] > 10000000) & (df['IPI - VINCULADO À IMPORTACAO'] > 5000000)
df_filtrados = df[filtro]
display(df_filtrados)
# Out:
#        Ano        Mês  UF  IMPOSTO SOBRE IMPORTAÇÃO  IMPOSTO SOBRE EXPORTAÇÃO  \
# 10    2000    Janeiro  MG              3.554918e+07                      57.0
# 17    2000    Janeiro  PR              4.598412e+07                       0.0
# 25    2000    Janeiro  SP              3.144761e+08                     943.0
# 39    2000  Fevereiro  MG              2.832180e+07                      13.0
# 42    2000  Fevereiro  PR              5.082031e+07                       0.0
# ...    ...        ...  ..                       ...                       ...
# 4991  2015       Maio  SC              3.334500e+08                  254410.0
# 4993  2015       Maio  SP              1.399145e+09                  739234.0
# 5094  2015   Setembro  RJ                       NaN                       NaN
# 5128  2015    Outubro  SP              1.757609e+09                       NaN
# 6775  2020   Novembro  SP              2.339871e+09                       NaN
#
#       IPI - FUMO  IPI - BEBIDAS  IPI_Automoveis  IPI - VINCULADO À IMPORTACAO  \
# 10    15511142.0     12111623.0      29305691.0                  1.504930e+07
# 17    10114872.0      5045577.0      12768408.0                  2.370262e+07
# 25    61452206.0     53883669.0      49619167.0                  1.766439e+08
# 39    14225672.0      8174782.0      45788926.0                  1.353928e+07
# 42     6395079.0      4440417.0      32178732.0                  3.023651e+07
# ...          ...            ...             ...                           ...
# 4991     42362.0     10143800.0      21352133.0                  1.430782e+08
# 4993      4277.0     86768172.0     182220254.0                  5.570230e+08
# 5094         NaN            NaN      27435501.0                  1.306543e+08
# 5128        24.0            NaN     190265195.0                  6.580042e+08
# 6775         NaN            NaN     199783137.0                  1.033097e+09
#
#       IPI - OUTROS  ...  REFIS  PAES  RETENÇÃO NA FONTE - LEI 10.833, Art. 30  \
# 10    3.866792e+07  ...    NaN   NaN                                      NaN
# 17    2.659616e+07  ...    NaN   NaN                                      NaN
# 25    2.917242e+08  ...    NaN   NaN                                      NaN
# 39    4.913726e+07  ...    NaN   NaN                                      NaN
# 42    2.525199e+07  ...    NaN   NaN                                      NaN
# ...            ...  ...    ...   ...                                      ...
# 4991  1.273495e+08  ...    NaN   NaN                                      NaN
# 4993  9.567938e+08  ...    NaN   NaN                                      NaN
# 5094           NaN  ...    NaN   NaN                                      NaN
# 5128           NaN  ...    NaN   NaN                                      NaN
# 6775  1.583899e+09  ...    NaN   NaN                                      NaN
#
#       PAGAMENTO UNIFICADO  OUTRAS RECEITAS ADMINISTRADAS  DEMAIS RECEITAS  \
# 10                    NaN                   1.190058e+06              NaN
# 17                    NaN                   8.813950e+05              NaN
# 25                    NaN                   1.308213e+07              NaN
# 39                    NaN                   9.771570e+05              NaN
# 42                    NaN                   6.985290e+05              NaN
# ...                   ...                            ...              ...
# 4991                  NaN                   4.907969e+07              NaN
# 4993                  NaN                   4.317659e+08              NaN
# 5094                  NaN                   1.075313e+09              NaN
# 5128                  NaN                            NaN              NaN
# 6775                  NaN                            NaN              NaN
#
#       RECEITA PREVIDENCIÁRIA  RECEITA PREVIDENCIÁRIA - PRÓPRIA  \
# 10                       NaN                               NaN
# 17                       NaN                               NaN
# 25                       NaN                               NaN
# 39                       NaN                               NaN
# 42                       NaN                               NaN
# ...                      ...                               ...
# 4991                     NaN                      1.054089e+09
# 4993                     NaN                      1.058906e+10
# 5094                     NaN                      3.231382e+09
# 5128                     NaN                      1.044852e+10
# 6775            1.528754e+10                               NaN
#
#       RECEITA PREVIDENCIÁRIA - DEMAIS  ADMINISTRADAS POR OUTROS ÓRGÃOS
# 10                                NaN                              NaN
# 17                                NaN                              NaN
# 25                                NaN                              NaN
# 39                                NaN                              NaN
# 42                                NaN                              NaN
# ...                               ...                              ...
# 4991                     1.188801e+08                     1.318262e+07
# 4993                     1.372536e+09                     1.096173e+08
# 5094                              NaN                     1.207612e+09
# 5128                     1.466626e+09                              NaN
# 6775                              NaN                              NaN
#
# [536 rows x 45 columns]

# %%
# AGRUPA POR ESTADO E SOMA A IMPORTAÇÃO
df['IMPOSTO SOBRE IMPORTAÇÃO'] = pd.to_numeric(df['IMPOSTO SOBRE IMPORTAÇÃO'], errors='coerce')

agregado = df.groupby('UF')['IMPOSTO SOBRE IMPORTAÇÃO'].sum()
display(agregado)
# Out:
# UF
# AC    7.784100e+05
# AL    4.400837e+07
# AM    2.695935e+09
# AP    9.910101e+06
# BA    3.498003e+09
# CE    1.844055e+09
# DF    2.667090e+08
# ES    1.545117e+10
# GO    1.889331e+09
# MA    3.682188e+08
# MG    4.833410e+09
# MS    4.827389e+07
# MT    1.729314e+08
# PA    3.069944e+08
# PB    3.384885e+08
# PE    3.371778e+09
# PI    3.365212e+07
# PR    1.480176e+10
# RJ    1.652531e+10
# RN    1.077542e+08
# RO    5.248072e+06
# RR    2.593379e+06
# RS    5.683958e+09
# SC    4.700164e+10
# SE    4.768141e+07
# SP    2.892485e+11
# TO    6.262692e+06
# Name: IMPOSTO SOBRE IMPORTAÇÃO, dtype: float64

# %%
# ESTADOS COM ARRECADAÇÃO DE IRPF É MAIOR QUE IRPJ
def arrecadacao_IRPF_IRPJ(df):
    return df[df['IRPF'] > df['IRPJ - DEMAIS EMPRESAS']]

df_IRPF_maior_IRPJ = arrecadacao_IRPF_IRPJ(df)
display(df_IRPF_maior_IRPJ)
# Out:
#        Ano    Mês  UF  IMPOSTO SOBRE IMPORTAÇÃO  IMPOSTO SOBRE EXPORTAÇÃO  \
# 81    2000  Abril  AC              6.900000e+01                       0.0
# 82    2000  Abril  AL              4.314960e+05                   34670.0
# 83    2000  Abril  AP              1.817600e+04                       0.0
# 86    2000  Abril  CE              6.404554e+06                       0.0
# 90    2000  Abril  MA              4.496161e+06                       0.0
# ...    ...    ...  ..                       ...                       ...
# 7246  2022   Maio  MG                       NaN                       NaN
# 7572  2023   Maio  MG                       NaN                       NaN
# 7575  2023   Maio  PR                       NaN                       NaN
# 7896  2024   Maio  MG                       NaN                       NaN
# 7908  2024   Maio  SP              1.899944e+09                       NaN
#
#       IPI - FUMO  IPI - BEBIDAS  IPI_Automoveis  IPI - VINCULADO À IMPORTACAO  \
# 81      281844.0            0.0             0.0                          53.0
# 82     1335161.0       666420.0             0.0                      209261.0
# 83      392010.0         1372.0          2089.0                       21265.0
# 86     4312128.0      3634189.0            75.0                     1170030.0
# 90      988884.0      2518789.0             0.0                      122391.0
# ...          ...            ...             ...                           ...
# 7246         NaN            NaN             NaN                           NaN
# 7572         NaN            NaN             NaN                           NaN
# 7575         0.0            NaN             NaN                           NaN
# 7896         NaN            NaN             NaN                           NaN
# 7908         NaN            NaN             NaN                   601329762.0
#
#       IPI - OUTROS  ...  REFIS  PAES  RETENÇÃO NA FONTE - LEI 10.833, Art. 30  \
# 81    1.533200e+04  ...    NaN   NaN                                      NaN
# 82    3.524041e+06  ...    NaN   NaN                                      NaN
# 83    5.564000e+03  ...    NaN   NaN                                      NaN
# 86    3.516949e+06  ...    NaN   NaN                                      NaN
# 90    1.185428e+06  ...    NaN   NaN                                      NaN
# ...            ...  ...    ...   ...                                      ...
# 7246           NaN  ...    NaN   NaN                                      NaN
# 7572           NaN  ...    NaN   NaN                                      NaN
# 7575           NaN  ...    NaN   NaN                                      NaN
# 7896           NaN  ...    NaN   NaN                                      NaN
# 7908  1.239712e+09  ...    NaN   NaN                                      NaN
#
#       PAGAMENTO UNIFICADO  OUTRAS RECEITAS ADMINISTRADAS  DEMAIS RECEITAS  \
# 81                    NaN                   1.601100e+04              NaN
# 82                    NaN                   1.368382e+06              NaN
# 83                    NaN                   7.293000e+03              NaN
# 86                    NaN                   1.416560e+05              NaN
# 90                    NaN                   6.171100e+04              NaN
# ...                   ...                            ...              ...
# 7246                  NaN                            NaN              NaN
# 7572                  NaN                            NaN              NaN
# 7575                  NaN                            NaN              NaN
# 7896                  NaN                            NaN              NaN
# 7908                  NaN                   1.030421e+09              NaN
#
#       RECEITA PREVIDENCIÁRIA  RECEITA PREVIDENCIÁRIA - PRÓPRIA  \
# 81                       NaN                               NaN
# 82                       NaN                               NaN
# 83                       NaN                               NaN
# 86                       NaN                               NaN
# 90                       NaN                               NaN
# ...                      ...                               ...
# 7246            3.896534e+09                               NaN
# 7572            4.379059e+09                               NaN
# 7575            2.953951e+09                               NaN
# 7896            4.745046e+09                               NaN
# 7908            1.968230e+10                               NaN
#
#       RECEITA PREVIDENCIÁRIA - DEMAIS  ADMINISTRADAS POR OUTROS ÓRGÃOS
# 81                                NaN                              NaN
# 82                                NaN                              NaN
# 83                                NaN                              NaN
# 86                                NaN                              NaN
# 90                                NaN                              NaN
# ...                               ...                              ...
# 7246                              NaN                              NaN
# 7572                              NaN                              NaN
# 7575                              NaN                              NaN
# 7896                              NaN                      118410499.0
# 7908                              NaN                              NaN
#
# [268 rows x 45 columns]

# %%
# CONVERTENDO VALORES PARA MILHÕES
df.rename(columns={ 'IMPOSTO SOBRE IMPORTAÇÃO': 'Importacao'}, inplace=True)

def converter_milhoes(valor):
    return valor / 1000000

df['Importação_milhoes'] = df['Importacao'].apply(converter_milhoes)


# ANÁLISE ANUAL por UF POR IMPORTAÇÃO
def ano_UF(df, coluna_valor):
    df_agrupado = df.groupby(['Ano', 'UF'])[coluna_valor].sum().reset_index()
    return df_agrupado

df_agrupado = ano_UF(df, 'Importacao')
display(df_agrupado)
# Out:
#       Ano  UF    Importacao
# 0    2000  AC  9.763000e+03
# 1    2000  AL  6.839260e+06
# 2    2000  AM  1.640991e+08
# 3    2000  AP  4.755260e+05
# 4    2000  BA  1.783387e+08
# ..    ...  ..           ...
# 670  2024  RS  0.000000e+00
# 671  2024  SC  1.076134e+10
# 672  2024  SE  0.000000e+00
# 673  2024  SP  1.592253e+10
# 674  2024  TO  0.000000e+00
#
# [675 rows x 3 columns]

# %%
def converter_mes_para_maiusculas(df):
    df['Mês'] = df['Mês'].str.upper()
    return df

df = converter_mes_para_maiusculas(df)
display(df)
# Out:
#        Ano      Mês  UF    Importacao  IMPOSTO SOBRE EXPORTAÇÃO  IPI - FUMO  \
# 0     2000  JANEIRO  AC  2.310000e+02                       0.0    292096.0
# 1     2000  JANEIRO  AL  4.750880e+05                   33873.0   1329338.0
# 2     2000  JANEIRO  AM  1.167940e+07                       0.0   1507146.0
# 3     2000  JANEIRO  AP  2.426700e+04                       0.0    424862.0
# 4     2000  JANEIRO  BA  1.047646e+07                      13.0   5542123.0
# ...    ...      ...  ..           ...                       ...         ...
# 7987  2024   AGOSTO  RR           NaN                       0.0         0.0
# 7988  2024   AGOSTO  SC  1.736928e+09                       NaN         0.0
# 7989  2024   AGOSTO  SP  2.349051e+09                       NaN         NaN
# 7990  2024   AGOSTO  SE           NaN                       NaN         0.0
# 7991  2024   AGOSTO  TO           NaN                       NaN         0.0
#
#       IPI - BEBIDAS  IPI_Automoveis  IPI - VINCULADO À IMPORTACAO  \
# 0               0.0             0.0                         167.0
# 1          812470.0             0.0                      141735.0
# 2         1791471.0         27796.0                     4414483.0
# 3            1419.0           321.0                       22333.0
# 4        11533707.0             0.0                     7496476.0
# ...             ...             ...                           ...
# 7987            0.0             NaN                           NaN
# 7988            NaN             NaN                           NaN
# 7989            NaN             NaN                           NaN
# 7990            NaN             0.0                           NaN
# 7991            NaN             0.0                           NaN
#
#       IPI - OUTROS  ...  PAES  RETENÇÃO NA FONTE - LEI 10.833, Art. 30  \
# 0     1.558000e+03  ...   NaN                                      NaN
# 1     3.676847e+06  ...   NaN                                      NaN
# 2     1.800346e+06  ...   NaN                                      NaN
# 3     1.216500e+04  ...   NaN                                      NaN
# 4     2.374386e+07  ...   NaN                                      NaN
# ...            ...  ...   ...                                      ...
# 7987           NaN  ...   NaN                                      NaN
# 7988           NaN  ...   NaN                                      NaN
# 7989  1.186723e+09  ...   NaN                                      NaN
# 7990           NaN  ...   NaN                                      NaN
# 7991           NaN  ...   NaN                                      NaN
#
#       PAGAMENTO UNIFICADO  OUTRAS RECEITAS ADMINISTRADAS  DEMAIS RECEITAS  \
# 0                     NaN                        20911.0              NaN
# 1                     NaN                       127189.0              NaN
# 2                     NaN                       187988.0              NaN
# 3                     NaN                        10769.0              NaN
# 4                     NaN                       536498.0              NaN
# ...                   ...                            ...              ...
# 7987                  NaN                            NaN              NaN
# 7988                  NaN                            NaN              NaN
# 7989                  NaN                            NaN              NaN
# 7990                  NaN                            NaN              NaN
# 7991                  NaN                            NaN              NaN
#
#       RECEITA PREVIDENCIÁRIA  RECEITA PREVIDENCIÁRIA - PRÓPRIA  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                        NaN                               NaN
# 4                        NaN                               NaN
# ...                      ...                               ...
# 7987                     NaN                               NaN
# 7988            2.807464e+09                               NaN
# 7989            1.955525e+10                               NaN
# 7990            2.842495e+08                               NaN
# 7991                     NaN                               NaN
#
#       RECEITA PREVIDENCIÁRIA - DEMAIS  ADMINISTRADAS POR OUTROS ÓRGÃOS  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                                 NaN                              NaN
# ...                               ...                              ...
# 7987                              NaN                              NaN
# 7988                              NaN                              NaN
# 7989                              NaN                      248925773.0
# 7990                              NaN                              NaN
# 7991                              NaN                              NaN
#
#       Importação_milhoes
# 0               0.000231
# 1               0.475088
# 2              11.679405
# 3               0.024267
# 4              10.476457
# ...                  ...
# 7987                 NaN
# 7988         1736.927996
# 7989         2349.051462
# 7990                 NaN
# 7991                 NaN
#
# [7992 rows x 46 columns]
